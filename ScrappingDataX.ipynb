# %% [markdown]
# ###**Soal 1 : Mengambil Data dari Sosial Media X (20%)**
# Mahasiswa diminta untuk menggunakan Twitter API untuk mengumpulkan data tweet mengenai topik yang telah ditentukan. Gunakan kata kunci Dapur Cokelat”.

# %% [markdown]
# **Menggunakan Tweet Harverst**

# %%
# Import required Python package
# !npx playwright install-deps
# !pip install pandas

#Input twitter token
twitter_auth_token = '' #<<<< TOKEN AUTH TWITTER (inspect -> Application -> Cookies -> auth_token)

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v

# Crawl Data with multiple keywords
filename = 'DavinaKaramoy.csv'
search_keyword = '("Davina Karamoy" OR "davina karamoy" OR "Davina karamoy") since:2025-01-01 until:2025-11-01 lang:id'
limit = 600

# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇Need to install the following packages:
# playwright@1.56.1
# Ok to proceed? (y) y
#
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏Installing dependencies...
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,149 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# ...

# %% [markdown]
# **Menampilkan hasil data yang berhasil dikumpulkan dalam bentuk DataFrame**

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=",")

# Display the DataFrame
display(df.head())

# Check the number of tweets collected
num_tweets = len(df)
print(f"Jumlah tweet dalam dataframe adalah {num_tweets}.")
# Out:
#    conversation_id_str                      created_at  favorite_count  \
# 0  1988862082297541057  Fri Nov 14 01:58:18 +0000 2025               0
# 1  1987130048844120505  Fri Nov 14 01:57:59 +0000 2025               0
# 2  1989149832536105333  Fri Nov 14 01:54:11 +0000 2025               0
# 3  1989149706333941896  Fri Nov 14 01:53:41 +0000 2025               0
# 4  1989149609957159403  Fri Nov 14 01:53:18 +0000 2025               0
#
#                                            full_text               id_str  \
# 0         @wleewleo jangan bongkar isi dapur plissss  1989150869976412279
# 1   Dia pikir ini dapur umum bisa seenaknya pergi...  1989150790288879832
# 2  Jadi Syarat Wajib Akademisi Unigal Ciamis Inga...  1989149832536105333
# 3  Babinsa Kel Kauman Kidul Melaksanakan monitori...  1989149706333941896
# 4  Penyusunan Key Performance Indicator sebagai d...  1989149609957159403
#
#                                          image_url in_reply_to_screen_name  \
# ...
